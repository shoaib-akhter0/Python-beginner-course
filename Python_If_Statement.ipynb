# %% [markdown]
# # **Python If Statement**
#
# Python supports the usual logical conditions from mathematics:
#
# Equals: a == b
#
# Not Equals: a != b
#
# Less than: a < b
#
# Less than or equal to: a <= b
#
# Greater than: a > b
#
# Greater than or equal to: a >= b
#
# These conditions can be used in several ways, most commonly in "if statements" and loops.
#
# An "**if statement**" is written by using the **if keyword.**

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
number = 15
if number > 0:
  print("The number is positive")
# Out:
# The number is positive

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age: 19
# You are eligible to vote.

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age: 9
# You are not eligible to vote.

# %% [markdown]
# # Even or Odd Number

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 21
# Odd Number

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 10
# Even Number

# %% [markdown]
# # Student Pass or Fail

# %%
marks = int(input("Enter your marks: "))

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks: 29
# Fail

# %%
marks = int(input("Enter your marks: "))

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks: 60
# Pass

# %% [markdown]
# # Login System

# %%
password = input("Enter password: ")

if password == "admin123":
    print("Login Successful")
else:
    print("Wrong Password")
# Out:
# Enter password: admin123
# Login Successful

# %%
password = input("Enter password: ")

if password == "admin123":
    print("Login Successful")
else:
    print("Wrong Password")
# Out:
# Enter password: shoaib
# Wrong Password

# %% [markdown]
# # ATM Balance Check

# %%
balance = 5000
withdraw = int(input("Enter amount to withdraw: "))

if withdraw <= balance:
    print("Transaction Successful")
else:
    print("Insufficient Balance")
# Out:
# Enter amount to withdraw: 60000
# Insufficient Balance

# %%
balance = 5000
withdraw = int(input("Enter amount to withdraw: "))

if withdraw <= balance:
    print("Transaction Successful")
else:
    print("Insufficient Balance")
# Out:
# Enter amount to withdraw: 4000
# Transaction Successful

# %% [markdown]
# # Traffic Light System

# %%
signal = input("Enter traffic signal color: ")

if signal == "red":
    print("Stop")
elif signal == "yellow":
    print("Get Ready")
elif signal == "green":
    print("Go")
else:
    print("Invalid Signal")
# Out:
# Enter traffic signal color: red
# Stop

# %% [markdown]
# # **Practice Questions**
#
# **Q1:** Write a program to find the largest number among three numbers.
#
#
# **Q2:**  Create a grading system using marks:
#
# * A = 80 and above
# * B = 70–79
# * C = 60–69
# * D = 50–59
# * Fail = below 50
#
# **Q3:** Create a simple calculator using if-elif-else:
#
# * Addition
#
# * Subtraction
#
# * Multiplication
#
# * Division
